# %% [markdown]
# # Exporation File for pipeline_practice_2.py

# %% [markdown]
# #### Import relevant libraries and data

# %%
import pandas as pd 

job_data = pd.read_csv("../data/jobs_practice_2.csv")
job_data
